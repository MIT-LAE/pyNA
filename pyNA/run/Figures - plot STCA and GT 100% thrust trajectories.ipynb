# %%
# Import 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pdb
from scipy.optimize import minimize

from IPython.display import clear_output
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
traj = dict()
traj['stca'] = pd.read_csv('../cases/stca/trajectory/STCB/V2/Trajectory_stca_750.0_1.0.csv')
traj['a10'] = pd.read_csv('../cases/a10/trajectory/STCB/V2/Trajectory_a10_750.0_1.0.csv')

# %%
plt.figure(figsize=(15,4))
plt.style.use('../utils/plot.mplstyle')
plt.plot(traj['stca']['X [m]'].values, traj['stca']['Z [m]'].values, label='NASA STCA')
plt.plot(traj['a10']['X [m]'].values, traj['a10']['Z [m]'].values, label='GT Medium SST')
plt.xlabel('X [m]')
plt.ylabel('Z [m]')
plt.legend(frameon=False)

# %%
traj['a10']['X [m]'].values[np.where(traj['a10']['Z [m]'].values<10.3)[0][-1]]/traj['stca']['X [m]'].values[np.where(traj['stca']['Z [m]'].values<10.3)[0][-1]]
# Out:
# 1.432706344754633
