# %%
# Imports
import os
import pdb
import numpy as np
import openmdao.api as om
import pandas as pd
import matplotlib.pyplot as plt
os.environ["pyna_language"] = 'python'
from pyNA.pyna import pyna
from pyNA.src.noise_timeseries import NoiseTimeSeries

from IPython.display import clear_output
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# Initialize pyna
py = pyna()

# Set config
py.case_name = 'nasa_stca_standard'
py.save_results = False
py.verification = True

# %%
# Plot results
py.plot_noise_source_distribution(timestep=152, metric='spl', components=('core','jet_mixing', 'airframe', 'fan_inlet', 'fan_discharge'))
# Out:
# Computing "core" source distribution
# Model viewer data has already has already been recorded for Driver.
# /Users/laurensvoet/Library/Python/3.7/lib/python/site-packages/openmdao/recorders/sqlite_recorder.py:224: UserWarning:The existing case recorder file, /Users/laurensvoet/Documents/Research/pyNA/pyNA/cases/nasa_stca_standard/dymos_solution.db, is being overwritten.
# Computing "jet_mixing" source distribution
# Model viewer data has already has already been recorded for Driver.
# Computing "airframe" source distribution
# Model viewer data has already has already been recorded for Driver.
# Computing "fan_inlet" source distribution
# Model viewer data has already has already been recorded for Driver.
# Computing "fan_discharge" source distribution
# Model viewer data has already has already been recorded for Driver.
