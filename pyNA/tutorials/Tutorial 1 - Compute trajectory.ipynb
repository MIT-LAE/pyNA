# %%
# Imports 
import os
import sys
from io import StringIO
sys.path.append("..")
os.environ["pyna_language"] = 'python'
import pdb
import numpy as np
import openmdao.api as om
import pandas as pd
pd.set_option('max_columns', None)
pd.set_option('max_rows', None)
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes, mark_inset
# %matplotlib inline
from pyNA.pyna import pyna

from IPython.display import clear_output
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# Load nasa stca standard trajectory
traj_nasa_std = pd.read_csv('../cases/nasa_stca_standard/trajectory/Trajectory_to.csv')

# Initialize pyna
py = pyna()

# Set config
py.case_name = 'stca'
py.atmosphere_type = 'stratified'
py.thrust_lapse = True
py.pkrot = False
py.k_rot = 1.27
py.max_iter = 50
py.TS_to = 0.88
py.TS_vnrs = 0.88
py.TS_cb = 0.61
py.z_cb = traj_nasa_std['Z [m]'][np.where(traj_nasa_std['TS [-]'] < 0.65)[0][0]]
py.z_max = traj_nasa_std['Z [m]'].values[-1]
py.v_max = traj_nasa_std['V [m/s]'].values[-1]
py.tolerance = 1e-3

# %%
# Compute trajectory
py.compute_trajectory()
# Out:
# /Users/laurensvoet/Library/Python/3.7/lib/python/site-packages/openmdao/utils/options_dictionary.py:332: OMDeprecationWarning:'gradient method' is not a valid python name and will become an invalid option name in a future release. You can prevent this warning (and future exceptions) by declaring this option using a valid python name.
# --- Linkage Report [phases] ---
#     --- groundroll - rotation ---
#         time           [final] ==  time           [initial]
#         states:x       [final] ==  states:x       [initial]
#         states:v       [final] ==  states:v       [initial]
#         states:alpha   [final] ==  states:alpha   [initial]
#     --- rotation - liftoff ---
#         time               [final] ==  time             [initial]
#         states:x           [final] ==  states:x         [initial]
#         parameters:z       [final*] ==  states:z         [initial]
#         states:v           [final] ==  states:v         [initial]
#         states:alpha       [final] ==  controls:alpha   [initial]
#         parameters:gamma   [final*] ==  states:gamma     [initial]
#     --- liftoff - vnrs ---
#         time             [final] ==  time             [initial]
#         states:x         [final] ==  states:x         [initial]
#         states:v         [final] ==  states:v         [initial]
#         controls:alpha   [final] ==  controls:alpha   [initial]
#         states:gamma     [final] ==  states:gamma     [initial]
#     --- vnrs - cutback ---
#         time             [final] ==  time             [initial]
#         states:x         [final] ==  states:x         [initial]
#         states:v         [final] ==  states:v         [initial]
#         controls:alpha   [final] ==  controls:alpha   [initial]
#         states:gamma     [final] ==  states:gamma     [initial]
#
# * : This quantity is fixed or is an input.
#
#
# --- Constraint Report [phases] ---
#     --- groundroll ---
#         [final]   0.0000e+00 == flight_dynamics.v_rot_residual [m/s]
#     --- rotation ---
#         [final]   1.1000e+00 == flight_dynamics.n [None]
#     --- liftoff ---
#         [path]    0.0000e+00 <= flight_dynamics.gamma_dot  [deg/s]
#         [path]    0.0000e+00 <= flight_dynamics.v_dot  [m/s**2]
#     --- vnrs ---
#         [path]    0.0000e+00 <= flight_dynamics.v_dot  [m/s**2]
#         [path]    0.0000e+00 <= gamma  [deg]
#     --- cutback ---
#         [final]   1.0965e+02 == v [m/s]
#         [path]    0.0000e+00 <= flight_dynamics.v_dot  [m/s**2]
# /Users/laurensvoet/Library/Python/3.7/lib/python/site-packages/openmdao/recorders/sqlite_recorder.py:224: UserWarning:The existing case recorder file, dymos_solution.db, is being overwritten.
# Model viewer data has already has already been recorded for Driver.
# Full total jacobian was computed 3 times, taking 5.686399 seconds.
# Total jacobian shape: (255, 178)
#
#
# Jacobian shape: (255, 178)  ( 3.77% nonzero)
# FWD solves: 11   REV solves: 0
# Total colors vs. total size: 11 vs 178  (93.8% improvement)
#
# Sparsity computed using tolerance: 1e-12
# Time to compute sparsity: 5.686399 sec.
# Time to compute coloring: 0.231222 sec.
#
#
# Optimization Problem -- Optimization using pyOpt_sparse
# ================================================================================
#     Objective Function: _objfunc
#
#     Solution:
# --------------------------------------------------------------------------------
#     Total Time:                    8.1851
#        User Objective Time :       0.7495
#        User Sensitivity Time :     6.5012
#        Interface Time :            0.8058
#        Opt Solver Time:            0.1286
#     Calls to Objective Function :      18
#     Calls to Sens Function :           18
#
#
#    Objectives
#       Index  Name                      Value          Optimum
#           0  trajectory.t_s     1.544821E-01     0.000000E+00
#
#    Variables (c - continuous, i - integer, d - discrete)
#       Index  Name                                                                   Type      Lower Bound            Value      Upper Bound     Status
#           0  phases.phases.groundroll.time_extents.t_duration_0                        c     0.000000E+00     2.692623E-01     1.000000E+00
#           1  phases.phases.groundroll.indep_states.states:x_0                          c    -1.000000E+18     1.504422E-01     1.000000E+18
#           2  phases.phases.groundroll.indep_states.states:x_1                          c    -1.000000E+18     5.822175E-01     1.000000E+18
#           3  phases.phases.groundroll.indep_states.states:x_2                          c    -1.000000E+18     1.264944E+00     1.000000E+18
#           4  phases.phases.groundroll.indep_states.states:v_0                          c    -1.000000E+19     3.298761E-01     1.000000E+19
#           5  phases.phases.groundroll.indep_states.states:v_1                          c    -1.000000E+19     6.265928E-01     1.000000E+19
#           6  phases.phases.groundroll.indep_states.states:v_2                          c    -1.000000E+19     8.889939E-01     1.000000E+19
#           7  phases.phases.groundroll.indep_states.states:alpha_0                      c    -2.000000E+00    -8.500000E-01     2.500000E+01
#           8  phases.phases.groundroll.indep_states.states:alpha_1                      c    -2.000000E+00    -8.500000E-01     2.500000E+01
#           9  phases.phases.groundroll.indep_states.states:alpha_2                      c    -2.000000E+00    -8.500000E-01     2.500000E+01
#          10  phases.phases.rotation.time_extents.t_initial_0                           c     1.000000E-01     2.692623E-01     1.000000E+00
#          11  phases.phases.rotation.time_extents.t_duration_0                          c     0.000000E+00     4.488713E-02     1.000000E+00
#          12  phases.phases.rotation.indep_states.states:x_0                            c    -1.000000E+18     1.264944E+00     1.000000E+18
#          13  phases.phases.rotation.indep_states.states:x_1                            c    -1.000000E+18     1.401023E+00     1.000000E+18
#          14  phases.phases.rotation.indep_states.states:x_2                            c    -1.000000E+18     1.543144E+00     1.000000E+18
#          15  phases.phases.rotation.indep_states.states:x_3                            c    -1.000000E+18     1.690597E+00     1.000000E+18
#          16  phases.phases.rotation.indep_states.states:v_0                            c    -1.000000E+19     8.889939E-01     1.000000E+19
#          17  phases.phases.rotation.indep_states.states:v_1                            c    -1.000000E+19     9.299023E-01     1.000000E+19
#          18  phases.phases.rotation.indep_states.states:v_2                            c    -1.000000E+19     9.692526E-01     1.000000E+19
#          19  phases.phases.rotation.indep_states.states:v_3                            c    -1.000000E+19     9.986562E-01     1.000000E+19
#          20  phases.phases.rotation.indep_states.states:alpha_0                        c    -2.000000E-01    -8.500000E-02     2.500000E+00
#          21  phases.phases.rotation.indep_states.states:alpha_1                        c    -2.000000E-01     4.386832E-01     2.500000E+00
#          22  phases.phases.rotation.indep_states.states:alpha_2                        c    -2.000000E-01     9.623664E-01     2.500000E+00
#          23  phases.phases.rotation.indep_states.states:alpha_3                        c    -2.000000E-01     1.486050E+00     2.500000E+00
#          24  phases.phases.liftoff.time_extents.t_initial_0                            c     2.000000E-01     3.141494E-01     2.000000E+00
#          25  phases.phases.liftoff.time_extents.t_duration_0                           c     0.000000E+00     6.016911E-02     5.000000E+00
#          26  phases.phases.liftoff.indep_states.states:x_0                             c    -1.000000E+17     1.690597E-01     1.000000E+17
#          27  phases.phases.liftoff.indep_states.states:x_1                             c    -1.000000E+17     1.842431E-01     1.000000E+17
#          28  phases.phases.liftoff.indep_states.states:x_2                             c    -1.000000E+17     1.997589E-01     1.000000E+17
#          29  phases.phases.liftoff.indep_states.states:x_3                             c    -1.000000E+17     2.155840E-01     1.000000E+17
#          30  phases.phases.liftoff.indep_states.states:x_4                             c    -1.000000E+17     2.316213E-01     1.000000E+17
#          31  phases.phases.liftoff.indep_states.states:z_0                             c    -1.000000E+20     0.000000E+00     1.000000E+20
#          32  phases.phases.liftoff.indep_states.states:z_1                             c    -1.000000E+20     5.229130E-02     1.000000E+20
#          33  phases.phases.liftoff.indep_states.states:z_2                             c    -1.000000E+20     1.849942E-01     1.000000E+20
#          34  phases.phases.liftoff.indep_states.states:z_3                             c    -1.000000E+20     4.546610E-01     1.000000E+20
#          35  phases.phases.liftoff.indep_states.states:v_0                             c    -1.000000E+19     9.986562E-01     1.000000E+19
#          36  phases.phases.liftoff.indep_states.states:v_1                             c    -1.000000E+19     1.020779E+00     1.000000E+19
#          37  phases.phases.liftoff.indep_states.states:v_2                             c    -1.000000E+19     1.042050E+00     1.000000E+19
#          38  phases.phases.liftoff.indep_states.states:v_3                             c    -1.000000E+19     1.061634E+00     1.000000E+19
#          39  phases.phases.liftoff.indep_states.states:v_4                             c    -1.000000E+19     1.069948E+00     1.000000E+19
#          40  phases.phases.liftoff.indep_states.states:gamma_0                         c    -1.000000E+20     0.000000E+00     1.000000E+20
#          41  phases.phases.liftoff.indep_states.states:gamma_1                         c    -1.000000E+20     2.897769E-02     1.000000E+20
#          42  phases.phases.liftoff.indep_states.states:gamma_2                         c    -1.000000E+20     7.234535E-02     1.000000E+20
#          43  phases.phases.liftoff.indep_states.states:gamma_3                         c    -1.000000E+20     1.336275E-01     1.000000E+20
#          44  phases.phases.liftoff.indep_states.states:gamma_4                         c    -1.000000E+20     3.291283E-01     1.000000E+20
#          45  phases.phases.liftoff.control_group.indep_controls.controls:alpha_0       c    -2.000000E-01     1.486050E+00     2.500000E+00
#          46  phases.phases.liftoff.control_group.indep_controls.controls:alpha_1       c    -2.000000E-01     1.380981E+00     2.500000E+00
#          47  phases.phases.liftoff.control_group.indep_controls.controls:alpha_2       c    -2.000000E-01     1.366267E+00     2.500000E+00
#          48  phases.phases.liftoff.control_group.indep_controls.controls:alpha_3       c    -2.000000E-01     1.378433E+00     2.500000E+00
#          49  phases.phases.liftoff.control_group.indep_controls.controls:alpha_4       c    -2.000000E-01     1.354005E+00     2.500000E+00
#          50  phases.phases.liftoff.control_group.indep_controls.controls:alpha_5       c    -2.000000E-01     1.345536E+00     2.500000E+00
#          51  phases.phases.liftoff.control_group.indep_controls.controls:alpha_6       c    -2.000000E-01     1.405584E+00     2.500000E+00
#          52  phases.phases.liftoff.control_group.indep_controls.controls:alpha_7       c    -2.000000E-01     1.493260E+00     2.500000E+00
#          53  phases.phases.liftoff.control_group.indep_controls.controls:alpha_8       c    -2.000000E-01     1.567680E+00     2.500000E+00
#          54  phases.phases.vnrs.time_extents.t_initial_0                               c     1.000000E-01     3.743185E-01     3.000000E+00
#          55  phases.phases.vnrs.time_extents.t_duration_0                              c     0.000000E+00     3.035871E-01     5.000000E+00
#          56  phases.phases.vnrs.indep_states.states:x_0                                c    -1.000000E+17     2.316213E-01     1.000000E+17
#          57  phases.phases.vnrs.indep_states.states:x_1                                c    -1.000000E+17     2.779189E-01     1.000000E+17
#          58  phases.phases.vnrs.indep_states.states:x_2                                c    -1.000000E+17     3.237968E-01     1.000000E+17
#          59  phases.phases.vnrs.indep_states.states:x_3                                c    -1.000000E+17     3.694761E-01     1.000000E+17
#          60  phases.phases.vnrs.indep_states.states:x_4                                c    -1.000000E+17     4.151377E-01     1.000000E+17
#          61  phases.phases.vnrs.indep_states.states:x_5                                c    -1.000000E+17     4.608392E-01     1.000000E+17
#          62  phases.phases.vnrs.indep_states.states:x_6                                c    -1.000000E+17     5.065979E-01     1.000000E+17
#          63  phases.phases.vnrs.indep_states.states:x_7                                c    -1.000000E+17     5.526290E-01     1.000000E+17
#          64  phases.phases.vnrs.indep_states.states:z_0                                c    -1.000000E+18     6.493563E-02     1.000000E+18
#          65  phases.phases.vnrs.indep_states.states:z_1                                c    -1.000000E+18     1.537625E-01     1.000000E+18
#          66  phases.phases.vnrs.indep_states.states:z_2                                c    -1.000000E+18     2.529280E-01     1.000000E+18
#          67  phases.phases.vnrs.indep_states.states:z_3                                c    -1.000000E+18     3.531699E-01     1.000000E+18
#          68  phases.phases.vnrs.indep_states.states:z_4                                c    -1.000000E+18     4.517550E-01     1.000000E+18
#          69  phases.phases.vnrs.indep_states.states:z_5                                c    -1.000000E+18     5.479034E-01     1.000000E+18
#          70  phases.phases.vnrs.indep_states.states:v_0                                c    -1.000000E+19     1.069948E+00     1.000000E+19
#          71  phases.phases.vnrs.indep_states.states:v_1                                c    -1.000000E+19     1.077371E+00     1.000000E+19
#          72  phases.phases.vnrs.indep_states.states:v_2                                c    -1.000000E+19     1.077704E+00     1.000000E+19
#          73  phases.phases.vnrs.indep_states.states:v_3                                c    -1.000000E+19     1.077846E+00     1.000000E+19
#          74  phases.phases.vnrs.indep_states.states:v_4                                c    -1.000000E+19     1.077971E+00     1.000000E+19
#          75  phases.phases.vnrs.indep_states.states:v_5                                c    -1.000000E+19     1.078039E+00     1.000000E+19
#          76  phases.phases.vnrs.indep_states.states:v_6                                c    -1.000000E+19     1.078192E+00     1.000000E+19
#          77  phases.phases.vnrs.indep_states.states:v_7                                c    -1.000000E+19     1.091575E+00     1.000000E+19
#          78  phases.phases.vnrs.indep_states.states:gamma_0                            c    -1.000000E+20     3.291283E-01     1.000000E+20
#          79  phases.phases.vnrs.indep_states.states:gamma_1                            c    -1.000000E+20     9.486759E-01     1.000000E+20
#          80  phases.phases.vnrs.indep_states.states:gamma_2                            c    -1.000000E+20     1.190921E+00     1.000000E+20
#          81  phases.phases.vnrs.indep_states.states:gamma_3                            c    -1.000000E+20     1.241174E+00     1.000000E+20
#          82  phases.phases.vnrs.indep_states.states:gamma_4                            c    -1.000000E+20     1.230192E+00     1.000000E+20
#          83  phases.phases.vnrs.indep_states.states:gamma_5                            c    -1.000000E+20     1.202881E+00     1.000000E+20
#          84  phases.phases.vnrs.indep_states.states:gamma_6                            c    -1.000000E+20     1.170488E+00     1.000000E+20
#          85  phases.phases.vnrs.indep_states.states:gamma_7                            c    -1.000000E+20     9.431918E-01     1.000000E+20
#          86  phases.phases.vnrs.control_group.indep_controls.controls:alpha_0          c     5.000000E-01     1.567680E+00     2.500000E+00
#          87  phases.phases.vnrs.control_group.indep_controls.controls:alpha_1          c     5.000000E-01     1.498421E+00     2.500000E+00
#          88  phases.phases.vnrs.control_group.indep_controls.controls:alpha_2          c     5.000000E-01     1.410270E+00     2.500000E+00
#          89  phases.phases.vnrs.control_group.indep_controls.controls:alpha_3          c     5.000000E-01     1.329123E+00     2.500000E+00
#          90  phases.phases.vnrs.control_group.indep_controls.controls:alpha_4          c     5.000000E-01     1.280877E+00     2.500000E+00
#          91  phases.phases.vnrs.control_group.indep_controls.controls:alpha_5          c     5.000000E-01     1.255511E+00     2.500000E+00
#          92  phases.phases.vnrs.control_group.indep_controls.controls:alpha_6          c     5.000000E-01     1.243003E+00     2.500000E+00
#          93  phases.phases.vnrs.control_group.indep_controls.controls:alpha_7          c     5.000000E-01     1.239162E+00     2.500000E+00
#          94  phases.phases.vnrs.control_group.indep_controls.controls:alpha_8          c     5.000000E-01     1.239800E+00     2.500000E+00
#          95  phases.phases.vnrs.control_group.indep_controls.controls:alpha_9          c     5.000000E-01     1.242850E+00     2.500000E+00
#          96  phases.phases.vnrs.control_group.indep_controls.controls:alpha_10         c     5.000000E-01     1.246248E+00     2.500000E+00
#          97  phases.phases.vnrs.control_group.indep_controls.controls:alpha_11         c     5.000000E-01     1.250707E+00     2.500000E+00
#          98  phases.phases.vnrs.control_group.indep_controls.controls:alpha_12         c     5.000000E-01     1.256946E+00     2.500000E+00
#          99  phases.phases.vnrs.control_group.indep_controls.controls:alpha_13         c     5.000000E-01     1.191811E+00     2.500000E+00
#         100  phases.phases.vnrs.control_group.indep_controls.controls:alpha_14         c     5.000000E-01     9.821497E-01     2.500000E+00
#         101  phases.phases.cutback.time_extents.t_initial_0                            c     1.000000E-01     6.779057E-01     4.000000E+00
#         102  phases.phases.cutback.time_extents.t_duration_0                           c     0.000000E+00     8.669149E-01     5.000000E+00
#         103  phases.phases.cutback.indep_states.states:x_0                             c    -1.000000E+17     5.526290E-01     1.000000E+17
#         104  phases.phases.cutback.indep_states.states:x_1                             c    -1.000000E+17     6.311268E-01     1.000000E+17
#         105  phases.phases.cutback.indep_states.states:x_2                             c    -1.000000E+17     7.100119E-01     1.000000E+17
#         106  phases.phases.cutback.indep_states.states:x_3                             c    -1.000000E+17     7.889290E-01     1.000000E+17
#         107  phases.phases.cutback.indep_states.states:x_4                             c    -1.000000E+17     8.678687E-01     1.000000E+17
#         108  phases.phases.cutback.indep_states.states:x_5                             c    -1.000000E+17     9.468286E-01     1.000000E+17
#         109  phases.phases.cutback.indep_states.states:x_6                             c    -1.000000E+17     1.025807E+00     1.000000E+17
#         110  phases.phases.cutback.indep_states.states:x_7                             c    -1.000000E+17     1.104803E+00     1.000000E+17
#         111  phases.phases.cutback.indep_states.states:x_8                             c    -1.000000E+17     1.183815E+00     1.000000E+17
#         112  phases.phases.cutback.indep_states.states:x_9                             c    -1.000000E+17     1.262841E+00     1.000000E+17
#         113  phases.phases.cutback.indep_states.states:x_10                            c    -1.000000E+17     1.341882E+00     1.000000E+17
#         114  phases.phases.cutback.indep_states.states:x_11                            c    -1.000000E+17     1.420935E+00     1.000000E+17
#         115  phases.phases.cutback.indep_states.states:z_0                             c    -1.000000E+18     7.272056E-01     1.000000E+18
#         116  phases.phases.cutback.indep_states.states:z_1                             c    -1.000000E+18     7.976840E-01     1.000000E+18
#         117  phases.phases.cutback.indep_states.states:z_2                             c    -1.000000E+18     8.649652E-01     1.000000E+18
#         118  phases.phases.cutback.indep_states.states:z_3                             c    -1.000000E+18     9.297883E-01     1.000000E+18
#         119  phases.phases.cutback.indep_states.states:z_4                             c    -1.000000E+18     9.923130E-01     1.000000E+18
#         120  phases.phases.cutback.indep_states.states:z_5                             c    -1.000000E+18     1.052628E+00     1.000000E+18
#         121  phases.phases.cutback.indep_states.states:z_6                             c    -1.000000E+18     1.110813E+00     1.000000E+18
#         122  phases.phases.cutback.indep_states.states:z_7                             c    -1.000000E+18     1.166944E+00     1.000000E+18
#         123  phases.phases.cutback.indep_states.states:z_8                             c    -1.000000E+18     1.221093E+00     1.000000E+18
#         124  phases.phases.cutback.indep_states.states:z_9                             c    -1.000000E+18     1.273331E+00     1.000000E+18
#         125  phases.phases.cutback.indep_states.states:z_10                            c    -1.000000E+18     1.323725E+00     1.000000E+18
#         126  phases.phases.cutback.indep_states.states:z_11                            c    -1.000000E+18     1.372343E+00     1.000000E+18
#         127  phases.phases.cutback.indep_states.states:v_0                             c    -1.000000E+19     1.091575E+00     1.000000E+19
#         128  phases.phases.cutback.indep_states.states:v_1                             c    -1.000000E+19     1.096251E+00     1.000000E+19
#         129  phases.phases.cutback.indep_states.states:v_2                             c    -1.000000E+19     1.096334E+00     1.000000E+19
#         130  phases.phases.cutback.indep_states.states:v_3                             c    -1.000000E+19     1.096364E+00     1.000000E+19
#         131  phases.phases.cutback.indep_states.states:v_4                             c    -1.000000E+19     1.096388E+00     1.000000E+19
#         132  phases.phases.cutback.indep_states.states:v_5                             c    -1.000000E+19     1.096409E+00     1.000000E+19
#         133  phases.phases.cutback.indep_states.states:v_6                             c    -1.000000E+19     1.096428E+00     1.000000E+19
#         134  phases.phases.cutback.indep_states.states:v_7                             c    -1.000000E+19     1.096444E+00     1.000000E+19
#         135  phases.phases.cutback.indep_states.states:v_8                             c    -1.000000E+19     1.096459E+00     1.000000E+19
#         136  phases.phases.cutback.indep_states.states:v_9                             c    -1.000000E+19     1.096473E+00     1.000000E+19
#         137  phases.phases.cutback.indep_states.states:v_10                            c    -1.000000E+19     1.096485E+00     1.000000E+19
#         138  phases.phases.cutback.indep_states.states:v_11                            c    -1.000000E+19     1.096499E+00     1.000000E+19
#         139  phases.phases.cutback.indep_states.states:v_12                            c    -1.000000E+19     1.096508E+00     1.000000E+19
#         140  phases.phases.cutback.indep_states.states:gamma_0                         c    -1.000000E+20     9.431918E-01     1.000000E+20
#         141  phases.phases.cutback.indep_states.states:gamma_1                         c    -1.000000E+20     5.287284E-01     1.000000E+20
#         142  phases.phases.cutback.indep_states.states:gamma_2                         c    -1.000000E+20     4.971038E-01     1.000000E+20
#         143  phases.phases.cutback.indep_states.states:gamma_3                         c    -1.000000E+20     4.780726E-01     1.000000E+20
#         144  phases.phases.cutback.indep_states.states:gamma_4                         c    -1.000000E+20     4.609785E-01     1.000000E+20
#         145  phases.phases.cutback.indep_states.states:gamma_5                         c    -1.000000E+20     4.446337E-01     1.000000E+20
#         146  phases.phases.cutback.indep_states.states:gamma_6                         c    -1.000000E+20     4.288939E-01     1.000000E+20
#         147  phases.phases.cutback.indep_states.states:gamma_7                         c    -1.000000E+20     4.137122E-01     1.000000E+20
#         148  phases.phases.cutback.indep_states.states:gamma_8                         c    -1.000000E+20     3.990787E-01     1.000000E+20
#         149  phases.phases.cutback.indep_states.states:gamma_9                         c    -1.000000E+20     3.849603E-01     1.000000E+20
#         150  phases.phases.cutback.indep_states.states:gamma_10                        c    -1.000000E+20     3.713600E-01     1.000000E+20
#         151  phases.phases.cutback.indep_states.states:gamma_11                        c    -1.000000E+20     3.582228E-01     1.000000E+20
#         152  phases.phases.cutback.indep_states.states:gamma_12                        c    -1.000000E+20     3.455791E-01     1.000000E+20
#         153  phases.phases.cutback.control_group.indep_controls.controls:alpha_0       c    -2.000000E-01     9.821497E-01     2.500000E+00
#         154  phases.phases.cutback.control_group.indep_controls.controls:alpha_1       c    -2.000000E-01     1.203569E+00     2.500000E+00
#         155  phases.phases.cutback.control_group.indep_controls.controls:alpha_2       c    -2.000000E-01     1.284587E+00     2.500000E+00
#         156  phases.phases.cutback.control_group.indep_controls.controls:alpha_3       c    -2.000000E-01     1.293782E+00     2.500000E+00
#         157  phases.phases.cutback.control_group.indep_controls.controls:alpha_4       c    -2.000000E-01     1.299731E+00     2.500000E+00
#         158  phases.phases.cutback.control_group.indep_controls.controls:alpha_5       c    -2.000000E-01     1.303880E+00     2.500000E+00
#         159  phases.phases.cutback.control_group.indep_controls.controls:alpha_6       c    -2.000000E-01     1.307674E+00     2.500000E+00
#         160  phases.phases.cutback.control_group.indep_controls.controls:alpha_7       c    -2.000000E-01     1.311242E+00     2.500000E+00
#         161  phases.phases.cutback.control_group.indep_controls.controls:alpha_8       c    -2.000000E-01     1.314710E+00     2.500000E+00
#         162  phases.phases.cutback.control_group.indep_controls.controls:alpha_9       c    -2.000000E-01     1.318101E+00     2.500000E+00
#         163  phases.phases.cutback.control_group.indep_controls.controls:alpha_10      c    -2.000000E-01     1.321441E+00     2.500000E+00
#         164  phases.phases.cutback.control_group.indep_controls.controls:alpha_11      c    -2.000000E-01     1.324728E+00     2.500000E+00
#         165  phases.phases.cutback.control_group.indep_controls.controls:alpha_12      c    -2.000000E-01     1.327960E+00     2.500000E+00
#         166  phases.phases.cutback.control_group.indep_controls.controls:alpha_13      c    -2.000000E-01     1.331143E+00     2.500000E+00
#         167  phases.phases.cutback.control_group.indep_controls.controls:alpha_14      c    -2.000000E-01     1.334279E+00     2.500000E+00
#         168  phases.phases.cutback.control_group.indep_controls.controls:alpha_15      c    -2.000000E-01     1.337366E+00     2.500000E+00
#         169  phases.phases.cutback.control_group.indep_controls.controls:alpha_16      c    -2.000000E-01     1.340402E+00     2.500000E+00
#         170  phases.phases.cutback.control_group.indep_controls.controls:alpha_17      c    -2.000000E-01     1.343390E+00     2.500000E+00
#         171  phases.phases.cutback.control_group.indep_controls.controls:alpha_18      c    -2.000000E-01     1.346338E+00     2.500000E+00
#         172  phases.phases.cutback.control_group.indep_controls.controls:alpha_19      c    -2.000000E-01     1.349237E+00     2.500000E+00
#         173  phases.phases.cutback.control_group.indep_controls.controls:alpha_20      c    -2.000000E-01     1.352080E+00     2.500000E+00
#         174  phases.phases.cutback.control_group.indep_controls.controls:alpha_21      c    -2.000000E-01     1.354882E+00     2.500000E+00
#         175  phases.phases.cutback.control_group.indep_controls.controls:alpha_22      c    -2.000000E-01     1.357658E+00     2.500000E+00
#         176  phases.phases.cutback.control_group.indep_controls.controls:alpha_23      c    -2.000000E-01     1.360379E+00     2.500000E+00
#         177  phases.phases.cutback.control_group.indep_controls.controls:alpha_24      c    -2.000000E-01     1.363014E+00     2.500000E+00
#
#    Constraints (i - inequality, e - equality)
#       Index  Name                                                                           Type          Lower           Value           Upper    Status  Lagrange Multiplier (N/A)
#           0  phases.phases.groundroll.final_boundary_constraints.final_value:v_rot_residual    e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#           1  phases.phases.groundroll.collocation_constraint.defects:x                         e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#           2  phases.phases.groundroll.collocation_constraint.defects:x                         e   0.000000E+00   -9.566119E-17    0.000000E+00              9.00000E+100
#           3  phases.phases.groundroll.collocation_constraint.defects:x                         e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#           4  phases.phases.groundroll.collocation_constraint.defects:v                         e   0.000000E+00   -1.992941E-17    0.000000E+00              9.00000E+100
#           5  phases.phases.groundroll.collocation_constraint.defects:v                         e   0.000000E+00   -1.992941E-17    0.000000E+00              9.00000E+100
#           6  phases.phases.groundroll.collocation_constraint.defects:v                         e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#           7  phases.phases.groundroll.collocation_constraint.defects:alpha                     e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#           8  phases.phases.groundroll.collocation_constraint.defects:alpha                     e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#           9  phases.phases.groundroll.collocation_constraint.defects:alpha                     e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#          10  phases.phases.rotation.final_boundary_constraints.final_value:n                   e   1.100000E+00    1.100000E+00    1.100000E+00              9.00000E+100
#          11  phases.phases.rotation.collocation_constraint.defects:x                           e   0.000000E+00   -2.126282E-17    0.000000E+00              9.00000E+100
#          12  phases.phases.rotation.collocation_constraint.defects:x                           e   0.000000E+00   -7.441986E-17    0.000000E+00              9.00000E+100
#          13  phases.phases.rotation.collocation_constraint.defects:x                           e   0.000000E+00   -4.252563E-17    0.000000E+00              9.00000E+100
#          14  phases.phases.rotation.collocation_constraint.defects:v                           e   0.000000E+00    2.325621E-17    0.000000E+00              9.00000E+100
#          15  phases.phases.rotation.collocation_constraint.defects:v                           e   0.000000E+00    9.966946E-18    0.000000E+00              9.00000E+100
#          16  phases.phases.rotation.collocation_constraint.defects:v                           e   0.000000E+00   -3.986778E-17    0.000000E+00              9.00000E+100
#          17  phases.phases.rotation.collocation_constraint.defects:alpha                       e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#          18  phases.phases.rotation.collocation_constraint.defects:alpha                       e   0.000000E+00   -1.328926E-16    0.000000E+00              9.00000E+100
#          19  phases.phases.rotation.collocation_constraint.defects:alpha                       e   0.000000E+00    1.328926E-16    0.000000E+00              9.00000E+100
#          20  phases.phases.liftoff.collocation_constraint.defects:x                            e   0.000000E+00   -1.171848E-07    0.000000E+00              9.00000E+100
#          21  phases.phases.liftoff.collocation_constraint.defects:x                            e   0.000000E+00   -4.163393E-07    0.000000E+00              9.00000E+100
#          22  phases.phases.liftoff.collocation_constraint.defects:x                            e   0.000000E+00   -9.748807E-07    0.000000E+00              9.00000E+100
#          23  phases.phases.liftoff.collocation_constraint.defects:x                            e   0.000000E+00   -8.975271E-07    0.000000E+00              9.00000E+100
#          24  phases.phases.liftoff.collocation_constraint.defects:z                            e   0.000000E+00   -9.395820E-06    0.000000E+00         E    9.00000E+100
#          25  phases.phases.liftoff.collocation_constraint.defects:z                            e   0.000000E+00    1.050306E-04    0.000000E+00         E    9.00000E+100
#          26  phases.phases.liftoff.collocation_constraint.defects:z                            e   0.000000E+00    9.621821E-04    0.000000E+00         E    9.00000E+100
#          27  phases.phases.liftoff.collocation_constraint.defects:z                            e   0.000000E+00   -2.690745E-04    0.000000E+00         E    9.00000E+100
#          28  phases.phases.liftoff.collocation_constraint.defects:v                            e   0.000000E+00   -2.534549E-06    0.000000E+00         E    9.00000E+100
#          29  phases.phases.liftoff.collocation_constraint.defects:v                            e   0.000000E+00   -8.580863E-06    0.000000E+00         E    9.00000E+100
#          30  phases.phases.liftoff.collocation_constraint.defects:v                            e   0.000000E+00   -1.458438E-05    0.000000E+00         E    9.00000E+100
#          31  phases.phases.liftoff.collocation_constraint.defects:v                            e   0.000000E+00    5.589085E-05    0.000000E+00         E    9.00000E+100
#          32  phases.phases.liftoff.collocation_constraint.defects:gamma                        e   0.000000E+00    4.365737E-05    0.000000E+00         E    9.00000E+100
#          33  phases.phases.liftoff.collocation_constraint.defects:gamma                        e   0.000000E+00    1.520296E-04    0.000000E+00         E    9.00000E+100
#          34  phases.phases.liftoff.collocation_constraint.defects:gamma                        e   0.000000E+00    1.917777E-04    0.000000E+00         E    9.00000E+100
#          35  phases.phases.liftoff.collocation_constraint.defects:gamma                        e   0.000000E+00   -5.814338E-04    0.000000E+00         E    9.00000E+100
#          36  phases.phases.liftoff.continuity_comp.defect_control_rates:alpha_rate             e   0.000000E+00    7.014118E-15    0.000000E+00              9.00000E+100
#          37  phases.phases.liftoff.continuity_comp.defect_control_rates:alpha_rate             e   0.000000E+00   -1.803630E-14    0.000000E+00              9.00000E+100
#          38  phases.phases.liftoff.continuity_comp.defect_control_rates:alpha_rate             e   0.000000E+00    7.348124E-15    0.000000E+00              9.00000E+100
#          39  phases.phases.vnrs.collocation_constraint.defects:x                               e   0.000000E+00    5.310756E-07    0.000000E+00              9.00000E+100
#          40  phases.phases.vnrs.collocation_constraint.defects:x                               e   0.000000E+00    3.440604E-07    0.000000E+00              9.00000E+100
#          41  phases.phases.vnrs.collocation_constraint.defects:x                               e   0.000000E+00    2.605836E-07    0.000000E+00              9.00000E+100
#          42  phases.phases.vnrs.collocation_constraint.defects:x                               e   0.000000E+00    2.077580E-07    0.000000E+00              9.00000E+100
#          43  phases.phases.vnrs.collocation_constraint.defects:x                               e   0.000000E+00    1.776841E-07    0.000000E+00              9.00000E+100
#          44  phases.phases.vnrs.collocation_constraint.defects:x                               e   0.000000E+00    1.049497E-07    0.000000E+00              9.00000E+100
#          45  phases.phases.vnrs.collocation_constraint.defects:x                               e   0.000000E+00    1.148860E-07    0.000000E+00              9.00000E+100
#          46  phases.phases.vnrs.collocation_constraint.defects:z                               e   0.000000E+00    2.230983E-06    0.000000E+00         E    9.00000E+100
#          47  phases.phases.vnrs.collocation_constraint.defects:z                               e   0.000000E+00    3.289190E-06    0.000000E+00         E    9.00000E+100
#          48  phases.phases.vnrs.collocation_constraint.defects:z                               e   0.000000E+00    2.835441E-06    0.000000E+00         E    9.00000E+100
#          49  phases.phases.vnrs.collocation_constraint.defects:z                               e   0.000000E+00    2.421664E-06    0.000000E+00         E    9.00000E+100
#          50  phases.phases.vnrs.collocation_constraint.defects:z                               e   0.000000E+00    1.800532E-06    0.000000E+00         E    9.00000E+100
#          51  phases.phases.vnrs.collocation_constraint.defects:z                               e   0.000000E+00    2.366367E-06    0.000000E+00         E    9.00000E+100
#          52  phases.phases.vnrs.collocation_constraint.defects:z                               e   0.000000E+00    8.260187E-07    0.000000E+00              9.00000E+100
#          53  phases.phases.vnrs.collocation_constraint.defects:v                               e   0.000000E+00    1.305497E-06    0.000000E+00         E    9.00000E+100
#          54  phases.phases.vnrs.collocation_constraint.defects:v                               e   0.000000E+00   -2.806890E-06    0.000000E+00         E    9.00000E+100
#          55  phases.phases.vnrs.collocation_constraint.defects:v                               e   0.000000E+00   -1.173054E-06    0.000000E+00         E    9.00000E+100
#          56  phases.phases.vnrs.collocation_constraint.defects:v                               e   0.000000E+00   -1.341980E-06    0.000000E+00         E    9.00000E+100
#          57  phases.phases.vnrs.collocation_constraint.defects:v                               e   0.000000E+00   -4.291451E-07    0.000000E+00              9.00000E+100
#          58  phases.phases.vnrs.collocation_constraint.defects:v                               e   0.000000E+00   -1.960427E-06    0.000000E+00         E    9.00000E+100
#          59  phases.phases.vnrs.collocation_constraint.defects:v                               e   0.000000E+00    2.375601E-06    0.000000E+00         E    9.00000E+100
#          60  phases.phases.vnrs.collocation_constraint.defects:gamma                           e   0.000000E+00   -2.642721E-05    0.000000E+00         E    9.00000E+100
#          61  phases.phases.vnrs.collocation_constraint.defects:gamma                           e   0.000000E+00    1.664598E-05    0.000000E+00         E    9.00000E+100
#          62  phases.phases.vnrs.collocation_constraint.defects:gamma                           e   0.000000E+00   -3.874573E-06    0.000000E+00         E    9.00000E+100
#          63  phases.phases.vnrs.collocation_constraint.defects:gamma                           e   0.000000E+00    8.610391E-07    0.000000E+00              9.00000E+100
#          64  phases.phases.vnrs.collocation_constraint.defects:gamma                           e   0.000000E+00   -5.639350E-06    0.000000E+00         E    9.00000E+100
#          65  phases.phases.vnrs.collocation_constraint.defects:gamma                           e   0.000000E+00    6.988497E-06    0.000000E+00         E    9.00000E+100
#          66  phases.phases.vnrs.collocation_constraint.defects:gamma                           e   0.000000E+00   -3.385560E-05    0.000000E+00         E    9.00000E+100
#          67  phases.phases.vnrs.continuity_comp.defect_control_rates:alpha_rate                e   0.000000E+00    6.235414E-14    0.000000E+00              9.00000E+100
#          68  phases.phases.vnrs.continuity_comp.defect_control_rates:alpha_rate                e   0.000000E+00   -1.221804E-14    0.000000E+00              9.00000E+100
#          69  phases.phases.vnrs.continuity_comp.defect_control_rates:alpha_rate                e   0.000000E+00   -3.107174E-14    0.000000E+00              9.00000E+100
#          70  phases.phases.vnrs.continuity_comp.defect_control_rates:alpha_rate                e   0.000000E+00   -3.725976E-14    0.000000E+00              9.00000E+100
#          71  phases.phases.vnrs.continuity_comp.defect_control_rates:alpha_rate                e   0.000000E+00    4.960946E-14    0.000000E+00              9.00000E+100
#          72  phases.phases.vnrs.continuity_comp.defect_control_rates:alpha_rate                e   0.000000E+00    6.214348E-15    0.000000E+00              9.00000E+100
#          73  phases.phases.cutback.final_boundary_constraints.final_value:v                    e   1.096508E+00    1.096508E+00    1.096508E+00              9.00000E+100
#          74  phases.phases.cutback.collocation_constraint.defects:x                            e   0.000000E+00    1.753316E-08    0.000000E+00              9.00000E+100
#          75  phases.phases.cutback.collocation_constraint.defects:x                            e   0.000000E+00    1.615481E-08    0.000000E+00              9.00000E+100
#          76  phases.phases.cutback.collocation_constraint.defects:x                            e   0.000000E+00    1.366528E-08    0.000000E+00              9.00000E+100
#          77  phases.phases.cutback.collocation_constraint.defects:x                            e   0.000000E+00    1.127267E-08    0.000000E+00              9.00000E+100
#          78  phases.phases.cutback.collocation_constraint.defects:x                            e   0.000000E+00    9.166223E-09    0.000000E+00              9.00000E+100
#          79  phases.phases.cutback.collocation_constraint.defects:x                            e   0.000000E+00    7.415481E-09    0.000000E+00              9.00000E+100
#          80  phases.phases.cutback.collocation_constraint.defects:x                            e   0.000000E+00    5.882797E-09    0.000000E+00              9.00000E+100
#          81  phases.phases.cutback.collocation_constraint.defects:x                            e   0.000000E+00    4.557583E-09    0.000000E+00              9.00000E+100
#          82  phases.phases.cutback.collocation_constraint.defects:x                            e   0.000000E+00    3.350839E-09    0.000000E+00              9.00000E+100
#          83  phases.phases.cutback.collocation_constraint.defects:x                            e   0.000000E+00    2.304824E-09    0.000000E+00              9.00000E+100
#          84  phases.phases.cutback.collocation_constraint.defects:x                            e   0.000000E+00    1.265104E-09    0.000000E+00              9.00000E+100
#          85  phases.phases.cutback.collocation_constraint.defects:x                            e   0.000000E+00    4.651031E-10    0.000000E+00              9.00000E+100
#          86  phases.phases.cutback.collocation_constraint.defects:z                            e   0.000000E+00    1.342076E-08    0.000000E+00              9.00000E+100
#          87  phases.phases.cutback.collocation_constraint.defects:z                            e   0.000000E+00    1.709070E-08    0.000000E+00              9.00000E+100
#          88  phases.phases.cutback.collocation_constraint.defects:z                            e   0.000000E+00    2.390035E-08    0.000000E+00              9.00000E+100
#          89  phases.phases.cutback.collocation_constraint.defects:z                            e   0.000000E+00    2.600857E-08    0.000000E+00              9.00000E+100
#          90  phases.phases.cutback.collocation_constraint.defects:z                            e   0.000000E+00    2.701032E-08    0.000000E+00              9.00000E+100
#          91  phases.phases.cutback.collocation_constraint.defects:z                            e   0.000000E+00    2.529435E-08    0.000000E+00              9.00000E+100
#          92  phases.phases.cutback.collocation_constraint.defects:z                            e   0.000000E+00    2.316079E-08    0.000000E+00              9.00000E+100
#          93  phases.phases.cutback.collocation_constraint.defects:z                            e   0.000000E+00    1.949479E-08    0.000000E+00              9.00000E+100
#          94  phases.phases.cutback.collocation_constraint.defects:z                            e   0.000000E+00    1.654941E-08    0.000000E+00              9.00000E+100
#          95  phases.phases.cutback.collocation_constraint.defects:z                            e   0.000000E+00    1.129772E-08    0.000000E+00              9.00000E+100
#          96  phases.phases.cutback.collocation_constraint.defects:z                            e   0.000000E+00    9.623296E-09    0.000000E+00              9.00000E+100
#          97  phases.phases.cutback.collocation_constraint.defects:z                            e   0.000000E+00    9.484114E-10    0.000000E+00              9.00000E+100
#          98  phases.phases.cutback.collocation_constraint.defects:v                            e   0.000000E+00   -5.192183E-08    0.000000E+00              9.00000E+100
# ...
#         162  phases.phases.liftoff.path_constraints.path:gamma_dot                             i   0.000000E+00    7.635196E-01    1.000000E+30              9.00000E+100
#         163  phases.phases.liftoff.path_constraints.path:gamma_dot                             i   0.000000E+00    1.320300E+00    1.000000E+30              9.00000E+100
#         164  phases.phases.liftoff.path_constraints.path:gamma_dot                             i   0.000000E+00    1.784255E+00    1.000000E+30              9.00000E+100
#         165  phases.phases.liftoff.path_constraints.path:v_dot                                 i   0.000000E+00    1.252550E+00    1.000000E+30              9.00000E+100
#         166  phases.phases.liftoff.path_constraints.path:v_dot                                 i   0.000000E+00    1.516285E+00    1.000000E+30              9.00000E+100
#         167  phases.phases.liftoff.path_constraints.path:v_dot                                 i   0.000000E+00    1.507811E+00    1.000000E+30              9.00000E+100
#         168  phases.phases.liftoff.path_constraints.path:v_dot                                 i   0.000000E+00    1.507811E+00    1.000000E+30              9.00000E+100
#         169  phases.phases.liftoff.path_constraints.path:v_dot                                 i   0.000000E+00    1.396788E+00    1.000000E+30              9.00000E+100
#         170  phases.phases.liftoff.path_constraints.path:v_dot                                 i   0.000000E+00    1.394223E+00    1.000000E+30              9.00000E+100
#         171  phases.phases.liftoff.path_constraints.path:v_dot                                 i   0.000000E+00    1.394223E+00    1.000000E+30              9.00000E+100
#         172  phases.phases.liftoff.path_constraints.path:v_dot                                 i   0.000000E+00    1.345755E+00    1.000000E+30              9.00000E+100
#         173  phases.phases.liftoff.path_constraints.path:v_dot                                 i   0.000000E+00    1.042244E+00    1.000000E+30              9.00000E+100
#         174  phases.phases.liftoff.path_constraints.path:v_dot                                 i   0.000000E+00    1.042244E+00    1.000000E+30              9.00000E+100
#         175  phases.phases.liftoff.path_constraints.path:v_dot                                 i   0.000000E+00    5.535415E-01    1.000000E+30              9.00000E+100
#         176  phases.phases.liftoff.path_constraints.path:v_dot                                 i   0.000000E+00    2.973979E-02    1.000000E+30              9.00000E+100
#         177  phases.phases.vnrs.path_constraints.path:v_dot                                    i   0.000000E+00    4.740349E-01    1.000000E+30              9.00000E+100
#         178  phases.phases.vnrs.path_constraints.path:v_dot                                    i   0.000000E+00    1.354502E-01    1.000000E+30              9.00000E+100
#         179  phases.phases.vnrs.path_constraints.path:v_dot                                    i   0.000000E+00    1.087073E-02    1.000000E+30              9.00000E+100
#         180  phases.phases.vnrs.path_constraints.path:v_dot                                    i   0.000000E+00    1.087073E-02    1.000000E+30              9.00000E+100
#         181  phases.phases.vnrs.path_constraints.path:v_dot                                    i   0.000000E+00    7.389381E-03    1.000000E+30              9.00000E+100
#         182  phases.phases.vnrs.path_constraints.path:v_dot                                    i   0.000000E+00    6.192298E-03    1.000000E+30              9.00000E+100
#         183  phases.phases.vnrs.path_constraints.path:v_dot                                    i   0.000000E+00    6.192298E-03    1.000000E+30              9.00000E+100
#         184  phases.phases.vnrs.path_constraints.path:v_dot                                    i   0.000000E+00    2.511982E-03    1.000000E+30              9.00000E+100
#         185  phases.phases.vnrs.path_constraints.path:v_dot                                    i   0.000000E+00    3.582845E-03    1.000000E+30              9.00000E+100
#         186  phases.phases.vnrs.path_constraints.path:v_dot                                    i   0.000000E+00    3.582845E-03    1.000000E+30              9.00000E+100
#         187  phases.phases.vnrs.path_constraints.path:v_dot                                    i   0.000000E+00    2.920521E-03    1.000000E+30              9.00000E+100
#         188  phases.phases.vnrs.path_constraints.path:v_dot                                    i   0.000000E+00    2.375169E-03    1.000000E+30              9.00000E+100
#         189  phases.phases.vnrs.path_constraints.path:v_dot                                    i   0.000000E+00    2.375169E-03    1.000000E+30              9.00000E+100
#         190  phases.phases.vnrs.path_constraints.path:v_dot                                    i   0.000000E+00    1.073909E-03    1.000000E+30              9.00000E+100
#         191  phases.phases.vnrs.path_constraints.path:v_dot                                    i   0.000000E+00    2.820738E-03    1.000000E+30              9.00000E+100
#         192  phases.phases.vnrs.path_constraints.path:v_dot                                    i   0.000000E+00    2.820738E-03    1.000000E+30              9.00000E+100
#         193  phases.phases.vnrs.path_constraints.path:v_dot                                    i   0.000000E+00    4.408302E-03    1.000000E+30              9.00000E+100
#         194  phases.phases.vnrs.path_constraints.path:v_dot                                    i   0.000000E+00    1.015260E-03    1.000000E+30              9.00000E+100
#         195  phases.phases.vnrs.path_constraints.path:v_dot                                    i   0.000000E+00    1.015260E-03    1.000000E+30              9.00000E+100
#         196  phases.phases.vnrs.path_constraints.path:v_dot                                    i   0.000000E+00    2.272016E-01    1.000000E+30              9.00000E+100
#         197  phases.phases.vnrs.path_constraints.path:v_dot                                    i   0.000000E+00    9.412483E-01    1.000000E+30              9.00000E+100
#         198  phases.phases.vnrs.path_constraints.path:gamma                                    i   0.000000E+00    3.291283E-01    1.000000E+30              9.00000E+100
#         199  phases.phases.vnrs.path_constraints.path:gamma                                    i   0.000000E+00    6.827314E-01    1.000000E+30              9.00000E+100
#         200  phases.phases.vnrs.path_constraints.path:gamma                                    i   0.000000E+00    9.486759E-01    1.000000E+30              9.00000E+100
#         201  phases.phases.vnrs.path_constraints.path:gamma                                    i   0.000000E+00    9.486759E-01    1.000000E+30              9.00000E+100
#         202  phases.phases.vnrs.path_constraints.path:gamma                                    i   0.000000E+00    1.108693E+00    1.000000E+30              9.00000E+100
#         203  phases.phases.vnrs.path_constraints.path:gamma                                    i   0.000000E+00    1.190921E+00    1.000000E+30              9.00000E+100
#         204  phases.phases.vnrs.path_constraints.path:gamma                                    i   0.000000E+00    1.190921E+00    1.000000E+30              9.00000E+100
#         205  phases.phases.vnrs.path_constraints.path:gamma                                    i   0.000000E+00    1.229170E+00    1.000000E+30              9.00000E+100
#         206  phases.phases.vnrs.path_constraints.path:gamma                                    i   0.000000E+00    1.241174E+00    1.000000E+30              9.00000E+100
#         207  phases.phases.vnrs.path_constraints.path:gamma                                    i   0.000000E+00    1.241174E+00    1.000000E+30              9.00000E+100
#         208  phases.phases.vnrs.path_constraints.path:gamma                                    i   0.000000E+00    1.239389E+00    1.000000E+30              9.00000E+100
#         209  phases.phases.vnrs.path_constraints.path:gamma                                    i   0.000000E+00    1.230192E+00    1.000000E+30              9.00000E+100
#         210  phases.phases.vnrs.path_constraints.path:gamma                                    i   0.000000E+00    1.230192E+00    1.000000E+30              9.00000E+100
#         211  phases.phases.vnrs.path_constraints.path:gamma                                    i   0.000000E+00    1.217653E+00    1.000000E+30              9.00000E+100
#         212  phases.phases.vnrs.path_constraints.path:gamma                                    i   0.000000E+00    1.202881E+00    1.000000E+30              9.00000E+100
#         213  phases.phases.vnrs.path_constraints.path:gamma                                    i   0.000000E+00    1.202881E+00    1.000000E+30              9.00000E+100
#         214  phases.phases.vnrs.path_constraints.path:gamma                                    i   0.000000E+00    1.186568E+00    1.000000E+30              9.00000E+100
#         215  phases.phases.vnrs.path_constraints.path:gamma                                    i   0.000000E+00    1.170488E+00    1.000000E+30              9.00000E+100
#         216  phases.phases.vnrs.path_constraints.path:gamma                                    i   0.000000E+00    1.170488E+00    1.000000E+30              9.00000E+100
#         217  phases.phases.vnrs.path_constraints.path:gamma                                    i   0.000000E+00    1.128707E+00    1.000000E+30              9.00000E+100
#         218  phases.phases.vnrs.path_constraints.path:gamma                                    i   0.000000E+00    9.431918E-01    1.000000E+30              9.00000E+100
#         219  phases.phases.cutback.path_constraints.path:v_dot                                 i   0.000000E+00    2.596198E-04    1.000000E+30              9.00000E+100
#         220  phases.phases.cutback.path_constraints.path:v_dot                                 i   0.000000E+00    9.695372E-02    1.000000E+30              9.00000E+100
#         221  phases.phases.cutback.path_constraints.path:v_dot                                 i   0.000000E+00    3.062883E-04    1.000000E+30              9.00000E+100
#         222  phases.phases.cutback.path_constraints.path:v_dot                                 i   0.000000E+00    3.062883E-04    1.000000E+30              9.00000E+100
#         223  phases.phases.cutback.path_constraints.path:v_dot                                 i   0.000000E+00    1.576669E-03    1.000000E+30              9.00000E+100
#         224  phases.phases.cutback.path_constraints.path:v_dot                                 i   0.000000E+00    2.615493E-04    1.000000E+30              9.00000E+100
#         225  phases.phases.cutback.path_constraints.path:v_dot                                 i   0.000000E+00    2.615493E-04    1.000000E+30              9.00000E+100
#         226  phases.phases.cutback.path_constraints.path:v_dot                                 i   0.000000E+00    4.728501E-04    1.000000E+30              9.00000E+100
#         227  phases.phases.cutback.path_constraints.path:v_dot                                 i   0.000000E+00    3.626486E-04    1.000000E+30              9.00000E+100
#         228  phases.phases.cutback.path_constraints.path:v_dot                                 i   0.000000E+00    3.626486E-04    1.000000E+30              9.00000E+100
#         229  phases.phases.cutback.path_constraints.path:v_dot                                 i   0.000000E+00    3.374347E-04    1.000000E+30              9.00000E+100
#         230  phases.phases.cutback.path_constraints.path:v_dot                                 i   0.000000E+00    2.969444E-04    1.000000E+30              9.00000E+100
#         231  phases.phases.cutback.path_constraints.path:v_dot                                 i   0.000000E+00    2.969444E-04    1.000000E+30              9.00000E+100
#         232  phases.phases.cutback.path_constraints.path:v_dot                                 i   0.000000E+00    2.913115E-04    1.000000E+30              9.00000E+100
#         233  phases.phases.cutback.path_constraints.path:v_dot                                 i   0.000000E+00    2.750846E-04    1.000000E+30              9.00000E+100
#         234  phases.phases.cutback.path_constraints.path:v_dot                                 i   0.000000E+00    2.750846E-04    1.000000E+30              9.00000E+100
#         235  phases.phases.cutback.path_constraints.path:v_dot                                 i   0.000000E+00    2.529505E-04    1.000000E+30              9.00000E+100
#         236  phases.phases.cutback.path_constraints.path:v_dot                                 i   0.000000E+00    2.397243E-04    1.000000E+30              9.00000E+100
#         237  phases.phases.cutback.path_constraints.path:v_dot                                 i   0.000000E+00    2.397243E-04    1.000000E+30              9.00000E+100
#         238  phases.phases.cutback.path_constraints.path:v_dot                                 i   0.000000E+00    2.333392E-04    1.000000E+30              9.00000E+100
#         239  phases.phases.cutback.path_constraints.path:v_dot                                 i   0.000000E+00    2.185985E-04    1.000000E+30              9.00000E+100
#         240  phases.phases.cutback.path_constraints.path:v_dot                                 i   0.000000E+00    2.185985E-04    1.000000E+30              9.00000E+100
#         241  phases.phases.cutback.path_constraints.path:v_dot                                 i   0.000000E+00    2.012406E-04    1.000000E+30              9.00000E+100
#         242  phases.phases.cutback.path_constraints.path:v_dot                                 i   0.000000E+00    1.992114E-04    1.000000E+30              9.00000E+100
#         243  phases.phases.cutback.path_constraints.path:v_dot                                 i   0.000000E+00    1.992114E-04    1.000000E+30              9.00000E+100
#         244  phases.phases.cutback.path_constraints.path:v_dot                                 i   0.000000E+00    2.019971E-04    1.000000E+30              9.00000E+100
#         245  phases.phases.cutback.path_constraints.path:v_dot                                 i   0.000000E+00    1.811744E-04    1.000000E+30              9.00000E+100
#         246  phases.phases.cutback.path_constraints.path:v_dot                                 i   0.000000E+00    1.811744E-04    1.000000E+30              9.00000E+100
#         247  phases.phases.cutback.path_constraints.path:v_dot                                 i   0.000000E+00    1.555084E-04    1.000000E+30              9.00000E+100
#         248  phases.phases.cutback.path_constraints.path:v_dot                                 i   0.000000E+00    1.732995E-04    1.000000E+30              9.00000E+100
#         249  phases.phases.cutback.path_constraints.path:v_dot                                 i   0.000000E+00    1.732995E-04    1.000000E+30              9.00000E+100
#         250  phases.phases.cutback.path_constraints.path:v_dot                                 i   0.000000E+00    2.003762E-04    1.000000E+30              9.00000E+100
#         251  phases.phases.cutback.path_constraints.path:v_dot                                 i   0.000000E+00    1.509029E-04    1.000000E+30              9.00000E+100
#         252  phases.phases.cutback.path_constraints.path:v_dot                                 i   0.000000E+00    1.509029E-04    1.000000E+30              9.00000E+100
#         253  phases.phases.cutback.path_constraints.path:v_dot                                 i   0.000000E+00    1.032458E-04    1.000000E+30              9.00000E+100
#         254  phases.phases.cutback.path_constraints.path:v_dot                                 i   0.000000E+00    2.369785E-04    1.000000E+30              9.00000E+100
#
# --------------------------------------------------------------------------------
# True

# %%
# Compare trajectory with NASA STCA trajectory
py.path.plot(traj_nasa_std)
